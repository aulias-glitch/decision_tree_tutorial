# %% [markdown]
# <a href="https://colab.research.google.com/github/aulias-glitch/decision_tree_tutorial/blob/main/data_understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Library

# %%
# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# NLP
import re
import string
from wordcloud import WordCloud

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# Ignore Warning
import warnings
warnings.filterwarnings('ignore')

# Display Setting
pd.set_option('display.max_columns', None)

print("Library berhasil diimport!")
# Out:
# Library berhasil diimport!

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv('/content/sample_submission.csv')

# %%
df = pd.read_csv('/content/test_labels.csv')

# %% [markdown]
# Tampilkan data

# %%
df.head()
# Out:
#                  id  toxic  severe_toxic  obscene  threat  insult  \
# 0  00001cee341fdb12     -1            -1       -1      -1      -1
# 1  0000247867823ef7     -1            -1       -1      -1      -1
# 2  00013b17ad220c46     -1            -1       -1      -1      -1
# 3  00017563c3f7919a     -1            -1       -1      -1      -1
# 4  00017695ad8997eb     -1            -1       -1      -1      -1
#
#    identity_hate
# 0             -1
# 1             -1
# 2             -1
# 3             -1
# 4             -1

# %% [markdown]
# Data Understanding

# %%
print(f"Jumlah Baris : {df.shape[0]}")
print(f"Jumlah Kolom : {df.shape[1]}")
# Out:
# Jumlah Baris : 153164
# Jumlah Kolom : 7

# %% [markdown]
# Informasi Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153164 entries, 0 to 153163
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             153164 non-null  object
#  1   toxic          153164 non-null  int64
#  2   severe_toxic   153164 non-null  int64
#  3   obscene        153164 non-null  int64
#  4   threat         153164 non-null  int64
#  5   insult         153164 non-null  int64
#  6   identity_hate  153164 non-null  int64
# dtypes: int64(6), object(1)
# memory usage: 8.2+ MB

# %% [markdown]
# Statistik Deskriptif

# %%
df.describe()
# Out:
#                toxic   severe_toxic        obscene         threat  \
# count  153164.000000  153164.000000  153164.000000  153164.000000
# mean       -0.542530      -0.579895      -0.558193      -0.580913
# std         0.572465       0.498408       0.542966       0.496195
# min        -1.000000      -1.000000      -1.000000      -1.000000
# 25%        -1.000000      -1.000000      -1.000000      -1.000000
# 50%        -1.000000      -1.000000      -1.000000      -1.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#               insult  identity_hate
# count  153164.000000  153164.000000
# mean       -0.559916      -0.577642
# std         0.539594       0.503260
# min        -1.000000      -1.000000
# 25%        -1.000000      -1.000000
# 50%        -1.000000      -1.000000
# 75%         0.000000       0.000000
# max         1.000000       1.000000

# %% [markdown]
# Melihat Nama Kolom

# %%
df.columns
# Out:
# Index(['id', 'toxic', 'severe_toxic', 'obscene', 'threat', 'insult',
#        'identity_hate'],
#       dtype='object')

# %% [markdown]
# Histogram

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df['toxic'],
    bins=50
)

plt.title("Distribusi Panjang Komentar")
plt.show()
